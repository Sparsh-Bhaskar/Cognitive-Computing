# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-17ad83d8-f0ae-4c20-bb40-8765cf69e414" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17ad83d8-f0ae-4c20-bb40-8765cf69e414">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('table.csv')

# %% [markdown]
# Question 2

# %%
df.loc[0]
# Out:
# Tid                    1
# Refund               Yes
# Marital Status    Single
# Taxable Income    125000
# Cheat                 No
# Name: 0, dtype: object

# %%
df.loc[4]
# Out:
# Tid                      5
# Refund                  No
# Marital Status    Divorced
# Taxable Income       95000
# Cheat                  Yes
# Name: 4, dtype: object

# %%
df.loc[7]
# Out:
# Tid                    8
# Refund                No
# Marital Status    Single
# Taxable Income     85000
# Cheat                Yes
# Name: 7, dtype: object

# %%
df.loc[8]
# Out:
# Tid                     9
# Refund                 No
# Marital Status    Married
# Taxable Income      75000
# Cheat                  No
# Name: 8, dtype: object

# %% [markdown]
# Question 3-1

# %%
df.iloc[3:8]
# Out:
#    Tid Refund Marital Status  Taxable Income Cheat
# 3    4    Yes        Married          120000    No
# 4    5     No       Divorced           95000   Yes
# 5    6     No        Married           60000    No
# 6    7    Yes       Divorced          220000    No
# 7    8     No         Single           85000   Yes

# %% [markdown]
# Question 3-2

# %%
df.iloc[4:9, 2:5]
# Out:
#   Marital Status  Taxable Income Cheat
# 4       Divorced           95000   Yes
# 5        Married           60000    No
# 6       Divorced          220000    No
# 7         Single           85000   Yes
# 8        Married           75000    No

# %% [markdown]
# Question 3-3

# %%
df.iloc[:, 1:4]
# Out:
#   Refund Marital Status  Taxable Income
# 0    Yes         Single          125000
# 1     No        Married          100000
# 2     No         Single           70000
# 3    Yes        Married          120000
# 4     No       Divorced           95000
# 5     No        Married           60000
# 6    Yes       Divorced          220000
# 7     No         Single           85000
# 8     No        Married           75000
# 9     No         Single           90000

# %% [markdown]
# Question 4

# %%
df.head()
# Out:
#    Tid Refund Marital Status  Taxable Income Cheat
# 0    1    Yes         Single          125000    No
# 1    2     No        Married          100000    No
# 2    3     No         Single           70000    No
# 3    4    Yes        Married          120000    No
# 4    5     No       Divorced           95000   Yes
