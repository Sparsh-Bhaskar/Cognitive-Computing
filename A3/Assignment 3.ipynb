# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-337affd8-1340-4384-b2b5-011712b18144" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-337affd8-1340-4384-b2b5-011712b18144">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('table.csv')

# %% [markdown]
# Question 2

# %%
df.loc[0]
# Out:
# Tid                    1
# Refund               Yes
# Marital Status    Single
# Taxable Income    125000
# Cheat                 No
# Name: 0, dtype: object

# %%
df.loc[4]
# Out:
# Tid                      5
# Refund                  No
# Marital Status    Divorced
# Taxable Income       95000
# Cheat                  Yes
# Name: 4, dtype: object

# %%
df.loc[7]
# Out:
# Tid                    8
# Refund                No
# Marital Status    Single
# Taxable Income     85000
# Cheat                Yes
# Name: 7, dtype: object

# %%
df.loc[8]
# Out:
# Tid                     9
# Refund                 No
# Marital Status    Married
# Taxable Income      75000
# Cheat                  No
# Name: 8, dtype: object

# %% [markdown]
# Question 3-1

# %%
df.iloc[3:8]
# Out:
#    Tid Refund Marital Status  Taxable Income Cheat
# 3    4    Yes        Married          120000    No
# 4    5     No       Divorced           95000   Yes
# 5    6     No        Married           60000    No
# 6    7    Yes       Divorced          220000    No
# 7    8     No         Single           85000   Yes

# %% [markdown]
# Question 3-2

# %%
df.iloc[4:9, 2:5]
# Out:
#   Marital Status  Taxable Income Cheat
# 4       Divorced           95000   Yes
# 5        Married           60000    No
# 6       Divorced          220000    No
# 7         Single           85000   Yes
# 8        Married           75000    No

# %% [markdown]
# Question 3-3

# %%
df.iloc[:, 1:4]
# Out:
#   Refund Marital Status  Taxable Income
# 0    Yes         Single          125000
# 1     No        Married          100000
# 2     No         Single           70000
# 3    Yes        Married          120000
# 4     No       Divorced           95000
# 5     No        Married           60000
# 6    Yes       Divorced          220000
# 7     No         Single           85000
# 8     No        Married           75000
# 9     No         Single           90000

# %% [markdown]
# Question 4

# %%
df.head()
# Out:
#    Tid Refund Marital Status  Taxable Income Cheat
# 0    1    Yes         Single          125000    No
# 1    2     No        Married          100000    No
# 2    3     No         Single           70000    No
# 3    4    Yes        Married          120000    No
# 4    5     No       Divorced           95000   Yes

# %% [markdown]
# Question 5

# %%
df.drop(df.columns[2],axis=1,inplace=True)

# %%
df.drop(3, axis = 0, inplace = True)
print(df)

# %% [markdown]
# Question 6

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7a15f9e7-cdef-4c9b-bba7-80aa79d83f6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a15f9e7-cdef-4c9b-bba7-80aa79d83f6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('Employee_Data.csv')

# %%
count = df.shape[1]
count2 = df.shape[0]
print(f"no. of columns are {count}")
print(f"no. of rows are {count2}")

# %% [markdown]
# Q6 - 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          5 non-null      int64
#  1   Name                 5 non-null      object
#  2   Department           5 non-null      object
#  3   Age                  5 non-null      int64
#  4   Salary               5 non-null      int64
#  5   Years_of_Experience  5 non-null      int64
#  6   Joining_Date         5 non-null      object
#  7   Gender               5 non-null      object
#  8   Bonus                5 non-null      int64
#  9   Rating               5 non-null      float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 532.0+ bytes

# %% [markdown]
# Q 6-3

# %%
df.describe()
# Out:
#        Employee_ID        Age       Salary  Years_of_Experience   Bonus  \
# count     5.000000   5.000000      5.00000             5.000000     5.0
# mean    103.000000  34.000000  60000.00000             7.400000  5500.0
# std       1.581139   5.612486   7905.69415             3.847077  1000.0
# min     101.000000  28.000000  50000.00000             3.000000  4500.0
# 25%     102.000000  29.000000  55000.00000             4.000000  5000.0
# 50%     103.000000  34.000000  60000.00000             8.000000  5000.0
# 75%     104.000000  38.000000  65000.00000            10.000000  6000.0
# max     105.000000  41.000000  70000.00000            12.000000  7000.0
#
#          Rating
# count  5.000000
# mean   4.100000
# std    0.494975
# min    3.500000
# 25%    3.800000
# 50%    4.000000
# 75%    4.500000
# max    4.700000

# %% [markdown]
# Q 6-4

# %%
df.loc[0:4]
# Out:
#    Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 0          101    Alice         HR   29   50000                    4
# 1          102      Bob         IT   34   70000                    8
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining_Date  Gender  Bonus  Rating
# 0   2020-03-15  Female   5000     4.5
# 1   2017-07-19    Male   7000     4.0
# 2   2013-06-01    Male   6000     3.8
# 3   2021-02-10  Female   4500     4.7
# 4   2010-11-25    Male   5000     3.5

# %%
df.loc[2:4]
# Out:
#    Employee_ID     Name Department  Age  Salary  Years_of_Experience  \
# 2          103  Charlie         IT   41   65000                   10
# 3          104    Diana  Marketing   28   55000                    3
# 4          105   Edward      Sales   38   60000                   12
#
#   Joining_Date  Gender  Bonus  Rating
# 2   2013-06-01    Male   6000     3.8
# 3   2021-02-10  Female   4500     4.7
# 4   2010-11-25    Male   5000     3.5

# %% [markdown]
# Q 6-5

# %%
df['Salary'].mean()
# Out:
# 60000.0

# %%
df["Bonus"].sum()
# Out:
# 27500

# %%
df["Age"].min()
# Out:
# 28

# %%
df["Rating"].max()
# Out:
# 4.7

# %% [markdown]
# Q 6-6

# %%
df["Salary"].sort_values(ascending = False)
# Out:
# 1    70000
# 2    65000
# 4    60000
# 3    55000
# 0    50000
# Name: Salary, dtype: int64

# %% [markdown]
# Q 6-7

# %%
def rate(Rating):
  if (Rating >= 4.5):
    return "Excellent"
  elif (Rating >= 4.0 and Rating < 4.5):
    return "Good"
  else:
    return "Average"

df['Performance Rating'] = df['Rating'].apply(rate)
df
# Out:
#     ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 0  101    Alice         HR   29   50000                    4   2020-03-15
# 1  102      Bob         IT   34   70000                    8   2017-07-19
# 2  103  Charlie         IT   41   65000                   10   2013-06-01
# 3  104    Diana  Marketing   28   55000                    3   2021-02-10
# 4  105   Edward      Sales   38   60000                   12   2010-11-25
#
#    Gender  Bonus  Rating Performance Rating     Tax
# 0  Female   5000     4.5          Excellent  5000.0
# 1    Male   7000     4.0               Good  7000.0
# 2    Male   6000     3.8            Average  6500.0
# 3  Female   4500     4.7          Excellent  5500.0
# 4    Male   5000     3.5            Average  6000.0

# %% [markdown]
# Q 6-8

# %%
df.isnull().sum()
# Out:
# Employee_ID            0
# Name                   0
# Department             0
# Age                    0
# Salary                 0
# Years_of_Experience    0
# Joining_Date           0
# Gender                 0
# Bonus                  0
# Rating                 0
# Performance Rating     0
# dtype: int64

# %% [markdown]
# Q 6-9

# %%
df.rename(columns = {'Employee_ID' : 'ID'}, inplace = True)
df
# Out:
#     ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 0  101    Alice         HR   29   50000                    4   2020-03-15
# 1  102      Bob         IT   34   70000                    8   2017-07-19
# 2  103  Charlie         IT   41   65000                   10   2013-06-01
# 3  104    Diana  Marketing   28   55000                    3   2021-02-10
# 4  105   Edward      Sales   38   60000                   12   2010-11-25
#
#    Gender  Bonus  Rating Performance Rating     Tax
# 0  Female   5000     4.5          Excellent  5000.0
# 1    Male   7000     4.0               Good  7000.0
# 2    Male   6000     3.8            Average  6500.0
# 3  Female   4500     4.7          Excellent  5500.0
# 4    Male   5000     3.5            Average  6000.0

# %% [markdown]
# Q 6-10

# %%
exp = []
exp.append(df[df['Years_of_Experience'] > 5])
exp
# Out:
# [    ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
#  1  102      Bob         IT   34   70000                    8   2017-07-19
#  2  103  Charlie         IT   41   65000                   10   2013-06-01
#  4  105   Edward      Sales   38   60000                   12   2010-11-25
#
#    Gender  Bonus  Rating Performance Rating
#  1   Male   7000     4.0               Good
#  2   Male   6000     3.8            Average
#  4   Male   5000     3.5            Average  ]

# %%
dep = []
dep.append(df[df['Department'] == 'IT'])
dep
# Out:
# [    ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
#  1  102      Bob         IT   34   70000                    8   2017-07-19
#  2  103  Charlie         IT   41   65000                   10   2013-06-01
#
#    Gender  Bonus  Rating Performance Rating
#  1   Male   7000     4.0               Good
#  2   Male   6000     3.8            Average  ]

# %% [markdown]
# Q 6-11

# %%
def tax(salary):
  return 0.1 * salary
df['Tax'] = df['Salary'].apply(tax)
df
# Out:
#     ID     Name Department  Age  Salary  Years_of_Experience Joining_Date  \
# 0  101    Alice         HR   29   50000                    4   2020-03-15
# 1  102      Bob         IT   34   70000                    8   2017-07-19
# 2  103  Charlie         IT   41   65000                   10   2013-06-01
# 3  104    Diana  Marketing   28   55000                    3   2021-02-10
# 4  105   Edward      Sales   38   60000                   12   2010-11-25
#
#    Gender  Bonus  Rating Performance Rating     Tax
# 0  Female   5000     4.5          Excellent  5000.0
# 1    Male   7000     4.0               Good  7000.0
# 2    Male   6000     3.8            Average  6500.0
# 3  Female   4500     4.7          Excellent  5500.0
# 4    Male   5000     3.5            Average  6000.0

# %% [markdown]
# Q 6-12

# %%
df.to_csv('Updated_EMP.csv', index = False)
